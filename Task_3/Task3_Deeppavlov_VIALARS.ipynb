# %%
# !pip install deeppavlov
# !pip install pyowm
# Out:
# Collecting deeppavlov
#   Downloading https://files.pythonhosted.org/packages/1c/d9/2c75603f26e59b2f058b057b26011bb1087a278b9a7c6173a930d75efd89/deeppavlov-0.3.0-py3-none-any.whl (677kB)
#      |████████████████████████████████| 686kB 4.9MB/s
# Collecting flask-cors==3.0.6 (from deeppavlov)
#   Downloading https://files.pythonhosted.org/packages/d1/db/f3495569d5c3e2bdb9fb8a66c54503364abb6f35a9da2227cf5c9c50dc42/Flask_Cors-3.0.6-py2.py3-none-any.whl
# Collecting flask==1.0.2 (from deeppavlov)
#   Downloading https://files.pythonhosted.org/packages/7f/e7/08578774ed4536d3242b14dacb4696386634607af824ea997202cd0edb4b/Flask-1.0.2-py2.py3-none-any.whl (91kB)
#      |████████████████████████████████| 92kB 33.4MB/s
# Collecting fuzzywuzzy==0.16.0 (from deeppavlov)
#   Downloading https://files.pythonhosted.org/packages/3b/36/be990a35c7e8ed9dc176c43b5699cd971cec0b6f9ef858843374171df4f2/fuzzywuzzy-0.16.0-py2.py3-none-any.whl
# Collecting keras==2.2.0 (from deeppavlov)
#   Downloading https://files.pythonhosted.org/packages/68/12/4cabc5c01451eb3b413d19ea151f36e33026fc0efb932bf51bcaf54acbf5/Keras-2.2.0-py2.py3-none-any.whl (300kB)
#      |████████████████████████████████| 307kB 56.8MB/s
# Requirement already satisfied: nltk==3.2.5 in /usr/local/lib/python3.6/dist-packages (from deeppavlov) (3.2.5)
# Collecting numpy==1.14.5 (from deeppavlov)
#   Downloading https://files.pythonhosted.org/packages/68/1e/116ad560de97694e2d0c1843a7a0075cc9f49e922454d32f49a80eb6f1f2/numpy-1.14.5-cp36-cp36m-manylinux1_x86_64.whl (12.2MB)
#      |████████████████████████████████| 12.2MB 43.5MB/s
# Collecting pymorphy2==0.8 (from deeppavlov)
#   Downloading https://files.pythonhosted.org/packages/a3/33/fff9675c68b5f6c63ec8c6e6ff57827dda28a1fa5b2c2d727dffff92dd47/pymorphy2-0.8-py2.py3-none-any.whl (46kB)
#      |████████████████████████████████| 51kB 26.0MB/s
# Collecting pytelegrambotapi==3.5.2 (from deeppavlov)
#   Downloading https://files.pythonhosted.org/packages/a4/5a/7aab147b253f19e5ef007316f39cf693a63d5cd7f654c3805c76f6bde979/pyTelegramBotAPI-3.5.2.tar.gz (51kB)
#      |████████████████████████████████| 61kB 29.6MB/s
# Collecting pandas==0.23.1 (from deeppavlov)
#   Downloading https://files.pythonhosted.org/packages/57/eb/6ab533ea8e35e7dd159af6922ac1123d4565d89f3926ad9a6aa46530978f/pandas-0.23.1-cp36-cp36m-manylinux1_x86_64.whl (11.8MB)
#      |████████████████████████████████| 11.8MB 26.2MB/s
# Requirement already satisfied: h5py==2.8.0 in /usr/local/lib/python3.6/dist-packages (from deeppavlov) (2.8.0)
# Collecting scikit-learn==0.19.1 (from deeppavlov)
#   Downloading https://files.pythonhosted.org/packages/3d/2d/9fbc7baa5f44bc9e88ffb7ed32721b879bfa416573e85031e16f52569bc9/scikit_learn-0.19.1-cp36-cp36m-manylinux1_x86_64.whl (12.4MB)
#      |████████████████████████████████| 12.4MB 42.0MB/s
# Collecting requests==2.19.1 (from deeppavlov)
#   Downloading https://files.pythonhosted.org/packages/65/47/7e02164a2a3db50ed6d8a6ab1d6d60b69c4c3fdf57a284257925dfc12bda/requests-2.19.1-py2.py3-none-any.whl (91kB)
#      |████████████████████████████████| 92kB 37.1MB/s
# Collecting rusenttokenize==0.0.4 (from deeppavlov)
#   Downloading https://files.pythonhosted.org/packages/f8/4c/e2aeee9cdcc266303289ad8c4acfdcf401781646bcc311ee2bf18f84d663/rusenttokenize-0.0.4-py3-none-any.whl
# Collecting flasgger==0.9.1 (from deeppavlov)
#   Downloading https://files.pythonhosted.org/packages/f7/4c/8735be27bebb88b0acbdc9db1d522583db10821aec3d3fb6112df0f41701/flasgger-0.9.1-py2.py3-none-any.whl (4.1MB)
#      |████████████████████████████████| 4.1MB 49.0MB/s
# Collecting tqdm==4.23.4 (from deeppavlov)
#   Downloading https://files.pythonhosted.org/packages/93/24/6ab1df969db228aed36a648a8959d1027099ce45fad67532b9673d533318/tqdm-4.23.4-py2.py3-none-any.whl (42kB)
#      |████████████████████████████████| 51kB 27.9MB/s
# Collecting Cython==0.28.5 (from deeppavlov)
#   Downloading https://files.pythonhosted.org/packages/19/8e/32b280abb0947a96cdbb8329fb2014851a21fc1d099009f946ea8a8202c3/Cython-0.28.5-cp36-cp36m-manylinux1_x86_64.whl (3.4MB)
#      |████████████████████████████████| 3.4MB 45.8MB/s
# Collecting pyopenssl==18.0.0 (from deeppavlov)
#   Downloading https://files.pythonhosted.org/packages/96/af/9d29e6bd40823061aea2e0574ccb2fcf72bfd6130ce53d32773ec375458c/pyOpenSSL-18.0.0-py2.py3-none-any.whl (53kB)
#      |████████████████████████████████| 61kB 34.1MB/s
# Collecting scipy==1.1.0 (from deeppavlov)
#   Downloading https://files.pythonhosted.org/packages/a8/0b/f163da98d3a01b3e0ef1cab8dd2123c34aee2bafbb1c5bffa354cc8a1730/scipy-1.1.0-cp36-cp36m-manylinux1_x86_64.whl (31.2MB)
#      |████████████████████████████████| 31.2MB 1.2MB/s
# Collecting pymorphy2-dicts-ru (from deeppavlov)
#   Downloading https://files.pythonhosted.org/packages/7c/9b/358faaff410f65a4ad159275e897b5956dcb20576c5b8e764b971c1634d7/pymorphy2_dicts_ru-2.4.404381.4453942-py2.py3-none-any.whl (8.0MB)
#      |████████████████████████████████| 8.0MB 41.9MB/s
# Collecting overrides==1.9 (from deeppavlov)
#   Downloading https://files.pythonhosted.org/packages/de/55/3100c6d14c1ed177492fcf8f07c4a7d2d6c996c0a7fc6a9a0a41308e7eec/overrides-1.9.tar.gz
# Requirement already satisfied: Six in /usr/local/lib/python3.6/dist-packages (from flask-cors==3.0.6->deeppavlov) (1.12.0)
# Requirement already satisfied: Jinja2>=2.10 in /usr/local/lib/python3.6/dist-packages (from flask==1.0.2->deeppavlov) (2.10.1)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.6/dist-packages (from flask==1.0.2->deeppavlov) (1.1.0)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.6/dist-packages (from flask==1.0.2->deeppavlov) (7.0)
# Requirement already satisfied: Werkzeug>=0.14 in /usr/local/lib/python3.6/dist-packages (from flask==1.0.2->deeppavlov) (0.15.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.2.0->deeppavlov) (3.13)
# Collecting keras-preprocessing==1.0.1 (from keras==2.2.0->deeppavlov)
#   Downloading https://files.pythonhosted.org/packages/f8/33/275506afe1d96b221f66f95adba94d1b73f6b6087cfb6132a5655b6fe338/Keras_Preprocessing-1.0.1-py2.py3-none-any.whl
# Collecting keras-applications==1.0.2 (from keras==2.2.0->deeppavlov)
#   Downloading https://files.pythonhosted.org/packages/e2/60/c557075e586e968d7a9c314aa38c236b37cb3ee6b37e8d57152b1a5e0b47/Keras_Applications-1.0.2-py2.py3-none-any.whl (43kB)
#      |████████████████████████████████| 51kB 27.3MB/s
# Collecting pymorphy2-dicts<3.0,>=2.4 (from pymorphy2==0.8->deeppavlov)
#   Downloading https://files.pythonhosted.org/packages/02/51/2465fd4f72328ab50877b54777764d928da8cb15b74e2680fc1bd8cb3173/pymorphy2_dicts-2.4.393442.3710985-py2.py3-none-any.whl (7.1MB)
#      |████████████████████████████████| 7.1MB 40.3MB/s
# Collecting dawg-python>=0.7 (from pymorphy2==0.8->deeppavlov)
#   Downloading https://files.pythonhosted.org/packages/6a/84/ff1ce2071d4c650ec85745766c0047ccc3b5036f1d03559fd46bb38b5eeb/DAWG_Python-0.7.2-py2.py3-none-any.whl
# Requirement already satisfied: docopt>=0.6 in /usr/local/lib/python3.6/dist-packages (from pymorphy2==0.8->deeppavlov) (0.6.2)
# Requirement already satisfied: python-dateutil>=2.5.0 in /usr/local/lib/python3.6/dist-packages (from pandas==0.23.1->deeppavlov) (2.5.3)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas==0.23.1->deeppavlov) (2018.9)
# Collecting urllib3<1.24,>=1.21.1 (from requests==2.19.1->deeppavlov)
#   Downloading https://files.pythonhosted.org/packages/bd/c9/6fdd990019071a4a32a5e7cb78a1d92c53851ef4f56f62a3486e6a7d8ffb/urllib3-1.23-py2.py3-none-any.whl (133kB)
#      |████████████████████████████████| 143kB 58.1MB/s
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests==2.19.1->deeppavlov) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests==2.19.1->deeppavlov) (2019.3.9)
# Collecting idna<2.8,>=2.5 (from requests==2.19.1->deeppavlov)
#   Downloading https://files.pythonhosted.org/packages/4b/2a/0276479a4b3caeb8a8c1af2f8e4355746a97fab05a372e4a2c6a6b876165/idna-2.7-py2.py3-none-any.whl (58kB)
#      |████████████████████████████████| 61kB 32.1MB/s
# Requirement already satisfied: jsonschema>=2.5.1 in /usr/local/lib/python3.6/dist-packages (from flasgger==0.9.1->deeppavlov) (2.6.0)
# Requirement already satisfied: mistune in /usr/local/lib/python3.6/dist-packages (from flasgger==0.9.1->deeppavlov) (0.8.4)
# Collecting cryptography>=2.2.1 (from pyopenssl==18.0.0->deeppavlov)
#   Downloading https://files.pythonhosted.org/packages/97/18/c6557f63a6abde34707196fb2cad1c6dc0dbff25a200d5044922496668a4/cryptography-2.7-cp34-abi3-manylinux1_x86_64.whl (2.3MB)
#      |████████████████████████████████| 2.3MB 52.3MB/s
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.10->flask==1.0.2->deeppavlov) (1.1.1)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /usr/local/lib/python3.6/dist-packages (from cryptography>=2.2.1->pyopenssl==18.0.0->deeppavlov) (1.12.3)
# Collecting asn1crypto>=0.21.0 (from cryptography>=2.2.1->pyopenssl==18.0.0->deeppavlov)
#   Downloading https://files.pythonhosted.org/packages/ea/cd/35485615f45f30a510576f1a56d1e0a7ad7bd8ab5ed7cdc600ef7cd06222/asn1crypto-0.24.0-py2.py3-none-any.whl (101kB)
#      |████████████████████████████████| 102kB 38.3MB/s
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi!=1.11.3,>=1.8->cryptography>=2.2.1->pyopenssl==18.0.0->deeppavlov) (2.19)
# Building wheels for collected packages: pytelegrambotapi, overrides
#   Building wheel for pytelegrambotapi (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/b0/a0/fa/c3539fd47aa9f834230d64039c4bc620463bc7afc39b0f3f35
#   Building wheel for overrides (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/8d/52/86/e5a83b1797e7d263b458d2334edd2704c78508b3eea9323718
# Successfully built pytelegrambotapi overrides
# ERROR: yellowbrick 0.9.1 has requirement scikit-learn>=0.20, but you'll have scikit-learn 0.19.1 which is incompatible.
# ERROR: tensorflow 1.13.1 has requirement keras-applications>=1.0.6, but you'll have keras-applications 1.0.2 which is incompatible.
# ERROR: tensorflow 1.13.1 has requirement keras-preprocessing>=1.0.5, but you'll have keras-preprocessing 1.0.1 which is incompatible.
# ERROR: spacy 2.0.18 has requirement numpy>=1.15.0, but you'll have numpy 1.14.5 which is incompatible.
# ERROR: imgaug 0.2.9 has requirement numpy>=1.15.0, but you'll have numpy 1.14.5 which is incompatible.
# ERROR: imbalanced-learn 0.4.3 has requirement scikit-learn>=0.20, but you'll have scikit-learn 0.19.1 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement pandas~=0.24.0, but you'll have pandas 0.23.1 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement requests~=2.21.0, but you'll have requests 2.19.1 which is incompatible.
# ERROR: fbprophet 0.5 has requirement pandas>=0.23.4, but you'll have pandas 0.23.1 which is incompatible.
# ERROR: fastai 1.0.52 has requirement numpy>=1.15, but you'll have numpy 1.14.5 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: flask, flask-cors, fuzzywuzzy, numpy, scipy, keras-preprocessing, keras-applications, keras, pymorphy2-dicts, dawg-python, pymorphy2, urllib3, idna, requests, pytelegrambotapi, pandas, scikit-learn, rusenttokenize, flasgger, tqdm, Cython, asn1crypto, cryptography, pyopenssl, pymorphy2-dicts-ru, overrides, deeppavlov
#   Found existing installation: Flask 1.0.3
#     Uninstalling Flask-1.0.3:
#       Successfully uninstalled Flask-1.0.3
#   Found existing installation: numpy 1.16.4
#     Uninstalling numpy-1.16.4:
#       Successfully uninstalled numpy-1.16.4
#   Found existing installation: scipy 1.3.0
#     Uninstalling scipy-1.3.0:
#       Successfully uninstalled scipy-1.3.0
#   Found existing installation: Keras-Preprocessing 1.0.9
#     Uninstalling Keras-Preprocessing-1.0.9:
#       Successfully uninstalled Keras-Preprocessing-1.0.9
#   Found existing installation: Keras-Applications 1.0.7
#     Uninstalling Keras-Applications-1.0.7:
#       Successfully uninstalled Keras-Applications-1.0.7
#   Found existing installation: Keras 2.2.4
#     Uninstalling Keras-2.2.4:
#       Successfully uninstalled Keras-2.2.4
#   Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Found existing installation: idna 2.8
#     Uninstalling idna-2.8:
#       Successfully uninstalled idna-2.8
#   Found existing installation: requests 2.21.0
#     Uninstalling requests-2.21.0:
#       Successfully uninstalled requests-2.21.0
#   Found existing installation: pandas 0.24.2
#     Uninstalling pandas-0.24.2:
#       Successfully uninstalled pandas-0.24.2
#   Found existing installation: scikit-learn 0.21.2
#     Uninstalling scikit-learn-0.21.2:
#       Successfully uninstalled scikit-learn-0.21.2
#   Found existing installation: tqdm 4.28.1
#     Uninstalling tqdm-4.28.1:
#       Successfully uninstalled tqdm-4.28.1
#   Found existing installation: Cython 0.29.9
#     Uninstalling Cython-0.29.9:
#       Successfully uninstalled Cython-0.29.9
# Successfully installed Cython-0.28.5 asn1crypto-0.24.0 cryptography-2.7 dawg-python-0.7.2 deeppavlov-0.3.0 flasgger-0.9.1 flask-1.0.2 flask-cors-3.0.6 fuzzywuzzy-0.16.0 idna-2.7 keras-2.2.0 keras-applications-1.0.2 keras-preprocessing-1.0.1 numpy-1.14.5 overrides-1.9 pandas-0.23.1 pymorphy2-0.8 pymorphy2-dicts-2.4.393442.3710985 pymorphy2-dicts-ru-2.4.404381.4453942 pyopenssl-18.0.0 pytelegrambotapi-3.5.2 requests-2.19.1 rusenttokenize-0.0.4 scikit-learn-0.19.1 scipy-1.1.0 tqdm-4.23.4 urllib3-1.23
# Collecting pyowm
#   Downloading https://files.pythonhosted.org/packages/41/2a/83e26bc87763d0d34767ddc5c875608d4a0a0da66e59730a15c55aec6eff/pyowm-2.10.0-py3-none-any.whl (3.7MB)
#      |████████████████████████████████| 3.8MB 4.7MB/s
# Collecting geojson<3,>=2.3.0 (from pyowm)
#   Downloading https://files.pythonhosted.org/packages/f1/34/bc3a65faabce27a7faa755ab08d811207a4fc438f77ef09c229fc022d778/geojson-2.4.1-py2.py3-none-any.whl
# Collecting requests<3,>=2.20.0 (from pyowm)
#   Downloading https://files.pythonhosted.org/packages/51/bd/23c926cd341ea6b7dd0b2a00aba99ae0f828be89d72b2190f27c11d4b7fb/requests-2.22.0-py2.py3-none-any.whl (57kB)
#      |████████████████████████████████| 61kB 30.7MB/s
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.20.0->pyowm) (2.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.20.0->pyowm) (2019.3.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.20.0->pyowm) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.20.0->pyowm) (1.23)
# ERROR: spacy 2.0.18 has requirement numpy>=1.15.0, but you'll have numpy 1.14.5 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement pandas~=0.24.0, but you'll have pandas 0.23.1 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement requests~=2.21.0, but you'll have requests 2.22.0 which is incompatible.
# ERROR: fastai 1.0.52 has requirement numpy>=1.15, but you'll have numpy 1.14.5 which is incompatible.
# ERROR: deeppavlov 0.3.0 has requirement requests==2.19.1, but you'll have requests 2.22.0 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# Installing collected packages: geojson, requests, pyowm
#   Found existing installation: requests 2.19.1
#     Uninstalling requests-2.19.1:
#       Successfully uninstalled requests-2.19.1
# Successfully installed geojson-2.4.1 pyowm-2.10.0 requests-2.22.0

# %%
import pyowm
import pandas as pd
import numpy as np
from deeppavlov import train_model
from datetime import datetime, timedelta

# %%
class WeatherChatBot():
  def __init__(self, country = 'Novosibirsk, RU'):
    self.country = country
    self._create_questions_answers()
    # !wget -nc https://raw.githubusercontent.com/ThomasVialars/DL_NLP/master/Task_3/tfidf_logreg_en_faq.json
    self.bot = train_model("/content/tfidf_logreg_en_faq.json", download = True)    
    
  def ask(self, questions):
    faq_answers = self.bot(questions)
    answers = []
    
    for i, score in enumerate(np.array(faq_answers[1])):
      if (score.max() > 0.9):
        answers.append(faq_answers[0][i][0])
      else:
        answers.append('I am sorry... I can\'t answer this question')
    return answers    
  
  def _create_questions_answers(self):
    days = {0 : "today", 1 : "tomorrow", 2 : "in two days", 3 : "in three days", 4 : "in four days"}  

    owm = pyowm.OWM('81eafa57483f61466c11276914ba8728')
    thf = owm.three_hours_forecast(self.country)

    start_date = thf.when_starts('date')
    questions = []

    for i in days:
      weather_i = thf.get_weather_at(thf.when_starts('date') + timedelta(days = i))

      questions += [["What is weather like " + days[i] + " ?", weather_i.get_detailed_status()],
                     ["How is the weather " + days[i] + " ?", weather_i.get_detailed_status()],
                     ["What is the temperature " + days[i] + " ?", weather_i.get_temperature(unit='celsius').get('temp')],
                     ["How much degrees outside " + days[i] + " ?",  weather_i.get_temperature(unit='celsius').get('temp')],
                     ["How much wind " + days[i] + " ?", weather_i.get_wind()],
                     ["What is the wind " + days[i] + " ?", weather_i.get_wind()],
                     ["What is the precipitation " + days[i] + " ?",  weather_i.get_rain()],
                     ["How much rain " + days[i] + " ?", weather_i.get_rain()]]

    df = pd.DataFrame(questions, columns=['Question', 'Answer'])
    df.to_csv('/content/faq_en.csv', index = 'False', sep=',', line_terminator='\n')

# %%
bot = WeatherChatBot()
# Out:
# --2019-06-01 12:09:02--  https://raw.githubusercontent.com/ThomasVialars/DL_NLP/master/Task_3/tfidf_logreg_en_faq.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2477 (2.4K) [text/plain]
# Saving to: ‘tfidf_logreg_en_faq.json’
#
# tfidf_logreg_en_faq 100%[===================>]   2.42K  --.-KB/s    in 0s
#
# 2019-06-01 12:09:02 (64.6 MB/s) - ‘tfidf_logreg_en_faq.json’ saved [2477/2477]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package perluniprops to /root/nltk_data...
# [nltk_data]   Unzipping misc/perluniprops.zip.
# [nltk_data] Downloading package nonbreaking_prefixes to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping corpora/nonbreaking_prefixes.zip.
# 2019-06-01 12:09:06.627 WARNING in 'deeppavlov.models.sklearn.sklearn_component'['sklearn_component'] at line 218: Cannot load model from /content/faq/tfidf.pkl
# 2019-06-01 12:09:06.628 INFO in 'deeppavlov.models.sklearn.sklearn_component'['sklearn_component'] at line 165: Initializing model sklearn.feature_extraction.text:TfidfVectorizer from scratch
# 2019-06-01 12:09:07.413 INFO in 'deeppavlov.models.sklearn.sklearn_component'['sklearn_component'] at line 108: Fitting model sklearn.feature_extraction.text:TfidfVectorizer
# 2019-06-01 12:09:07.417 INFO in 'deeppavlov.models.sklearn.sklearn_component'['sklearn_component'] at line 240: Saving model to /content/faq/tfidf.pkl
# 2019-06-01 12:09:07.429 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 89: [saving vocabulary to /content/faq/answers.dict]
# 2019-06-01 12:09:07.433 WARNING in 'deeppavlov.models.sklearn.sklearn_component'['sklearn_component'] at line 218: Cannot load model from /content/faq/logreg.pkl
# 2019-06-01 12:09:07.434 INFO in 'deeppavlov.models.sklearn.sklearn_component'['sklearn_component'] at line 165: Initializing model sklearn.linear_model:LogisticRegression from scratch
# 2019-06-01 12:09:07.457 INFO in 'deeppavlov.models.sklearn.sklearn_component'['sklearn_component'] at line 108: Fitting model sklearn.linear_model:LogisticRegression
# 2019-06-01 12:09:07.464 INFO in 'deeppavlov.models.sklearn.sklearn_component'['sklearn_component'] at line 240: Saving model to /content/faq/logreg.pkl
# 2019-06-01 12:09:07.814 INFO in 'deeppavlov.models.sklearn.sklearn_component'['sklearn_component'] at line 202: Loading model sklearn.feature_extraction.text:TfidfVectorizer from /content/faq/tfidf.pkl
# 2019-06-01 12:09:07.818 INFO in 'deeppavlov.models.sklearn.sklearn_component'['sklearn_component'] at line 209: Model sklearn.feature_extraction.textTfidfVectorizer loaded  with parameters
# 2019-06-01 12:09:07.819 WARNING in 'deeppavlov.models.sklearn.sklearn_component'['sklearn_component'] at line 215: Fitting of loaded model can not be continued. Model can be fitted from scratch.If one needs to continue fitting, please, look at `warm_start` parameter
# 2019-06-01 12:09:07.823 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 103: [loading vocabulary from /content/faq/answers.dict]
# 2019-06-01 12:09:07.824 INFO in 'deeppavlov.models.sklearn.sklearn_component'['sklearn_component'] at line 202: Loading model sklearn.linear_model:LogisticRegression from /content/faq/logreg.pkl
# 2019-06-01 12:09:07.826 INFO in 'deeppavlov.models.sklearn.sklearn_component'['sklearn_component'] at line 209: Model sklearn.linear_model.logisticLogisticRegression loaded  with parameters
# 2019-06-01 12:09:07.828 WARNING in 'deeppavlov.models.sklearn.sklearn_component'['sklearn_component'] at line 215: Fitting of loaded model can not be continued. Model can be fitted from scratch.If one needs to continue fitting, please, look at `warm_start` parameter
# 2019-06-01 12:09:08.148 INFO in 'deeppavlov.models.sklearn.sklearn_component'['sklearn_component'] at line 202: Loading model sklearn.feature_extraction.text:TfidfVectorizer from /content/faq/tfidf.pkl
# 2019-06-01 12:09:08.150 INFO in 'deeppavlov.models.sklearn.sklearn_component'['sklearn_component'] at line 209: Model sklearn.feature_extraction.textTfidfVectorizer loaded  with parameters
# 2019-06-01 12:09:08.151 WARNING in 'deeppavlov.models.sklearn.sklearn_component'['sklearn_component'] at line 215: Fitting of loaded model can not be continued. Model can be fitted from scratch.If one needs to continue fitting, please, look at `warm_start` parameter
# 2019-06-01 12:09:08.153 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 103: [loading vocabulary from /content/faq/answers.dict]
# 2019-06-01 12:09:08.155 INFO in 'deeppavlov.models.sklearn.sklearn_component'['sklearn_component'] at line 202: Loading model sklearn.linear_model:LogisticRegression from /content/faq/logreg.pkl
# 2019-06-01 12:09:08.157 INFO in 'deeppavlov.models.sklearn.sklearn_component'['sklearn_component'] at line 209: Model sklearn.linear_model.logisticLogisticRegression loaded  with parameters
# 2019-06-01 12:09:08.158 WARNING in 'deeppavlov.models.sklearn.sklearn_component'['sklearn_component'] at line 215: Fitting of loaded model can not be continued. Model can be fitted from scratch.If one needs to continue fitting, please, look at `warm_start` parameter

# %%
bot.ask(['What is the weather like today?'])
# Out:
# ['scattered clouds']

# %%
bot.ask(['How is the weather tomorrow?'])
# Out:
# ['light rain']

# %%
bot.ask(['How much degrees outside in four days?'])
# Out:
# ['18.55']

# %%
bot.ask(['How much degrees outside in three days?', 'How much wind in three days?', 'What is the precipitation in three days?'])
# Out:
# ['15.85', "{'speed': 2.36, 'deg': 264.5}", '{}']

# %%
bot.ask(['How did the Game of Thrones end?'])
# Out:
# ["I am sorry... I can't answer this question"]
